# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Part 6.1
# ### S = {1, 2, 3}, V from 4 to 20
#
# - Sequential
# - Thread
# - Process

# %%
x1 = [i for i in range (4, 21)]

yseq = [2236.000000, 1000.000000, 3089.000000, 842.000000, 1618.000000, 1661.000000, 815.000000, 1012.000000, 1560.000000, 1227.000000, 1162.000000, 974.000000, 1098.000000, 2336.000000, 1707.000000, 1235.000000, 1346.000000]



plt.figure(num=None, figsize=(8,6), dpi=80, facecolor='w', edgecolor='k')
plt.title("Sequential Method\nTime Against V", fontsize=20)
plt.xlabel("Value of V", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

plt.plot(x1, yseq, marker = 'o', label='thing1')

# plt.legend(loc='upper left')
plt.show()

# %%
x = [i for i in range (4, 21)]

ythread = [1131.000000, 943.000000, 1281.000000, 1656.000000, 2336.000000, 1762.000000, 2077.000000, 2677.000000, 3975.000000, 4119.000000, 3087.000000, 3724.000000, 2709.000000, 4056.000000, 4792.000000, 4462.000000, 4103.000000]




plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title("Threads Method\nTime Against V", fontsize=20)
plt.xlabel("Value of V", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

plt.plot(x1, ythread, marker = 'o', label='thing1')

# plt.legend(loc='upper left')
plt.show()

# %%
x = [i for i in range (4, 21)]

y1 = [3520.000000, 3186.000000, 3644.000000, 3955.000000, 5160.000000, 4108.000000, 5072.000000, 5155.000000, 4984.000000, 6411.000000, 17820.000000, 7126.000000, 9951.000000, 7374.000000, 9807.000000, 13003.000000, 10310.000000]
yproc = [1365.000000, 1462.000000, 1033.000000, 1455.000000, 1203.000000, 1834.000000, 2269.000000, 549.000000, 543.000000, 910.000000, 778.000000, 1509.000000, 2090.000000, 2125.000000, 1289.000000, 2685.000000, 3055.000000]
y3 = [1351.000000, 1107.000000, 2164.000000, 1398.000000, 1268.000000, 1394.000000, 1576.000000, 1287.000000, 1013.000000, 799.000000, 800.000000, 1676.000000, 1322.000000, 1940.000000, 868.000000, 1031.000000, 1808.000000]


plt.figure(num=None, figsize=(8,6), dpi=80, facecolor='w', edgecolor='k')
plt.title("Processes Method\nTime Against V", fontsize=20)
plt.xlabel("Value of V", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

# plt.plot(x, y1, marker = 'o', label='thing1')
plt.plot(x, yproc, marker = 'o', label='thing2')
# plt.plot(x, y3, marker = 'o', label='thing3')

# plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(num=None, figsize=(8,6 ), dpi=80, facecolor='w', edgecolor='k')
plt.title("All Methods\nTime Against V", fontsize=20)
plt.xlabel("Value of V", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

plt.plot(x, yseq, marker = 'o', label='Sequential')
plt.plot(x, ythread, marker = 'o', label='Threads')
plt.plot(x, yproc, marker = 'o', label='Processes')

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Part 6.2
# ### S = {1, 2, 3, 5, 8, 9, 10}, where m is varied from 3 to 7, and V fixed to 10.
#
# - Sequential
# - Thread
# - Process

# %%
xnew = [i for i in range (3, 8)]

yseq2 = [3104.000000, 3479.000000, 3311.000000, 905.000000, 1229.000000]




plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title("Sequential Method\nTime Against m", fontsize=20)
plt.xlabel("Value of m", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

plt.plot(xnew, yseq2, marker = 'o', label='thing1')

# plt.legend(loc='upper left')
plt.show()

# %%
xnew = [i for i in range (3, 8)]

ythread2 = [3383.000000, 15027.000000, 4784.000000, 5385.000000, 6076.000000]




plt.figure(num=None, figsize=(8,6), dpi=80, facecolor='w', edgecolor='k')
plt.title("Threads Method\nTime Against m", fontsize=20)
plt.xlabel("Value of m", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

plt.plot(xnew, ythread2, marker = 'o', label='thing1')

# plt.legend(loc='upper left')
plt.show()

# %%
xnew = [i for i in range (3, 8)]

yprocess2 = [5767.000000, 6337.000000, 6648.000000, 14350.000000, 10151.000000]
y8 = [8288.000000, 6026.000000, 6379.000000, 10407.000000, 11561.000000]



plt.figure(num=None, figsize=(8,6), dpi=80, facecolor='w', edgecolor='k')
plt.title("Processes Method\nTime Against m", fontsize=20)
plt.xlabel("Value of m", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

plt.plot(xnew, yprocess2, marker = 'o', label='thing1')
# plt.plot(xnew, y8, marker = 'o', label='thing2')
# plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.title("All Methods\nTime Against m", fontsize=20)
plt.xlabel("Value of m", fontsize=15)
plt.ylabel("Time taken (microsecond)", fontsize=15)

plt.plot(xnew, yseq2, marker = 'o', label='Sequential')
plt.plot(xnew, ythread2, marker = 'o', label='Threads')
plt.plot(xnew, yprocess2, marker = 'o', label='Processes')
plt.legend(loc='upper left')
plt.show()
